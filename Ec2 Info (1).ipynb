# %% [markdown]
# # Main Confusions While Working on AWS Ec2 Instance

# %% [raw]
# ✅SECTION 1: Understanding EC2 describe_instances() Output
# 🎯 Your Insight:
# The output is a dictionary with two keys: Reservations and ResponseMetadata.
#
# ✅ Correction / Clarification:
# ✔️ Yes, describe_instances() returns a dictionary.
#
# Here is my Mistake. I created 2 instances individually. So I had 2 ReservationId and the length of the returned list from Reservations was also 2. From that I conclude the number of elements in the list will be equal to number of ec2 instances. Which was wrong. If multiple Instances are created at once len will still be 1. and more than 1 if ec2 created individually
# ✔️ Reservations is a list, not always length 1. One reservation can have multiple instances if launched together.
#
# ✔️ Instances inside each reservation is also a list of instance dictionaries.
#
# ✔️ ResponseMetadata holds API request info (e.g., request ID, HTTP code, headers).
#
# ✅ SECTION 2: Accessing Dictionary Data in Python
# 🎯 Your Questions:
# Can we use len() on a dict? Yes
#
# Why does dict.get() use [] sometimes?
#
# What’s the difference between dict['key']
#
# ✅ Clarifications:
# ✔️ len(dict) gives you the number of keys in that dictionary.
#
# ✔️ dict.get('key', []) is used to safely return an empty list if the key doesn't exist (especially for fields like 'Tags' or 'Instances').
#
# ✔️ dict['key'] raises a KeyError if the key is missing, while dict.get('key') returns None (or a default value you provide).
#
#
# ✅ SECTION 4: Looping Through Reservations and Instances
# 🎯 Your Code:
# python
# Copy
# Edit
# for item in totalInstances:
#     print(item['Instances'][0]['InstanceId'])
# ✅ Limitation:
# ❌ Assumes only one instance per reservation. This is Wrong Assumptions, works only if ec2 are created individually.
# But if Multiple Instances are created at once only the first 1 id will be fetched
#
# ✔️ Better to loop through all instances:
#
# for res in response['Reservations']:  # res is a dic with 4 keys. 1 : ReservationId, Owner, Groups, and Instances
#     for inst in res['Instances']: # although res['Instances'] is a list. and inst is a dict with 40+ keys
#         print(inst['InstanceId']) # InstanceId  is 1 key out of  that 40+ from dictionary inst
#
# ✅ SECTION 5: List Comprehensions and Tags
#
# [tag['Value'] for tag in instance.get('Tags', []) if tag['Key'] == 'Name']
# ✅ Clarification:
# ✔️ Yes, it's a list comprehension.
#
# ✔️ It filters for the 'Name' tag and returns its value.
#
# ✔️ Safer than instance['Tags'] because not all instances have tags.
#
# ✅ SECTION 6: NetworkInterfaces Block
# 🎯 You Asked:
# From this block, what’s most important?
#
# ✅ Answer:
# Focus on these keys:
#
# NetworkInterfaceId
#
# PrivateIpAddress
#
# PublicIp (from 'Association')
#
# SubnetId, VpcId
#
# Groups[] (Security groups)
#
# DeleteOnTermination
#
# Status
#
# SourceDestCheck
#
# These fields matter most for security, networking, automation, and cost control in real-world enterprise systems.
#
# ✅ SECTION 7: Your Final Observations
# 🎯 You said:
# I observed that one reservation maps to one instance.
#
# ✅ Clarification:
# ✔️ That’s true only if you launch one instance per request.
#
# ❌ Not always true — a single reservation can include multiple instances if launched together using MinCount > 1.
#
# ✅ KEY TAKEAWAYS:
# Concept	Correct Usage / Best Practice
# Top-level structure	dict with Reservations (list) and ResponseMetadata
# Safe key access	Use dict.get('key', default)
# List of instances	Loop through ['Reservations'][i]['Instances'][j]
# Count total instances	Use sum(len(res['Instances']) for res in Reservations)
# Extract tags safely	Use list comprehension or next()
# Public IP or DNS	instance.get('NetworkInterfaces', [])[0].get('Association', {}).get('PublicIp')
# Print key info	Use f-strings or structured loops
# Reservations vs Instances	Don’t assume 1-to-1 — check both list lengths

# %%
import boto3
import json

# Create EC2 client
ec2 = boto3.client('ec2')

# Call describe_instances
response = ec2.describe_instances()      # This is a dictionary with main 2 keys : Reservations and ResponseMetadata

# Optional: Pretty-print full output like aws cli
print(json.dumps(response, indent=4,default = str))
# Out:
# {
#     "Reservations": [
#         {
#             "ReservationId": "r-0887bec7c2e48b1e8",
#             "OwnerId": "120569645542",
#             "Groups": [],
#             "Instances": [
#                 {
#                     "Architecture": "x86_64",
#                     "BlockDeviceMappings": [
#                         {
#                             "DeviceName": "/dev/sda1",
#                             "Ebs": {
#                                 "AttachTime": "2025-07-10 14:25:48+00:00",
#                                 "DeleteOnTermination": true,
#                                 "Status": "attached",
#                                 "VolumeId": "vol-0b8d295d79a7ffb83"
#                             }
#                         }
#                     ],
#                     "ClientToken": "b5df8917-5e2a-42ed-ad9f-0d888f67fd4b",
#                     "EbsOptimized": false,
#                     "EnaSupport": true,
#                     "Hypervisor": "xen",
# ...

# %%
# There are 2 Main Keys in response dictionary
for key in response:
    print(key)
# Out:
# Reservations
# ResponseMetadata

# %%
# Type of Value of response['Reservations'] is list of dictionary. Because response itself is a dictionary
print(f"Type of Value of response['Reservations'] vlaues is: ", type(response['Reservations'])) # This is a dictionary
print(f"The len of Reservation Values in list: ", len (response['Reservations'])) # The len shows the number of instances running
# if and only if they are created individually
# But If Multiple Instances are Created at once. The length of list will Still be 1. But have Multiple Instance Id 1 for each ec2
print(f"Type of Value of response['ResponseMetadata'] is: ", type(response['ResponseMetadata']))
# Out:
# Type of Value of response['Reservations'] vlaues is:  <class 'list'>
# The len of Reservation Values in list:  2
# Type of Value of response['ResponseMetadata'] is:  <class 'dict'>

# %%
# There are only 4 Keys in response['Reservations']
for key in response['Reservations'][0]: # Because the returned value is a list. that's why we picked the 1 element to get keys
    print(key)
# Out:
# ReservationId
# OwnerId
# Groups
# Instances

# %%
ReservationValue_list = response['Reservations']    # These are values in Reservatins key only and is python list

# %% [markdown]
# ### Most Common Monitoring Parameter from Ec2 Instance

# %%
# These are all the keys and values in Instances key of response['Reservations']
for reser in response['Reservations']:
    for key in reser['Instances'][0]:
        print(key,": ", reser['Instances'][0][key])
    break
# Out:
# Architecture :  x86_64
# BlockDeviceMappings :  [{'DeviceName': '/dev/sda1', 'Ebs': {'AttachTime': datetime.datetime(2025, 7, 10, 14, 25, 48, tzinfo=tzutc()), 'DeleteOnTermination': True, 'Status': 'attached', 'VolumeId': 'vol-0b8d295d79a7ffb83'}}]
# ClientToken :  b5df8917-5e2a-42ed-ad9f-0d888f67fd4b
# EbsOptimized :  False
# EnaSupport :  True
# Hypervisor :  xen
# ...

# %%
# dict.get(key) is used when we are not sure whether the key will exists or not. Good Practice to be safe
# dict.get(key,[]) # In the above case if no key found returns None. while in this syntax returns empty list. Good Practice.
total_ec2 = 0
for reservation in response['Reservations']:
    for instance in reservation['Instances']:
        total_ec2 += 1
        #General Most Important to Monitor Regularly
        print(f"ID: {instance['InstanceId']}")
        print(f"Name: {[tag['Value'] for tag in instance.get('Tags', []) if tag['Key'] == 'Name']}") # Tags is a dictionary
        print(f"Type: {instance['InstanceType']}")
        print(f"State: {instance['State']['Name']}")
        print(f"Private IP: {instance.get('PrivateIpAddress')}")
        print(f"Public IP: {instance.get('PublicIpAddress', 'N/A')}")
        print(f"AZ: {instance['Placement']['AvailabilityZone']}") # The Value itself is a Dictioary 
        print(f"Key Pair: {instance.get('KeyName')}")
        print(f"Launch Time: {instance['LaunchTime']}")
        print()
        eni = instance['NetworkInterfaces'][0]  # Assuming 1st ENI

        #These are the Most Common From NetworkInterface key in Instances Key 
        print("ENI ID:", eni['NetworkInterfaceId'])
        print("Private IP:", eni['PrivateIpAddress'])
        print("Public IP:", eni.get('Association', {}).get('PublicIp', 'None'))
        print("Public DNS:", eni.get('Association', {}).get('PublicDnsName', 'None'))
        print("Subnet ID:", eni['SubnetId'])
        print("VPC ID:", eni['VpcId'])
        print("MAC Address:", eni['MacAddress'])
        print("Security Group(s):", [g['GroupName'] for g in eni['Groups']])
        print("Delete on Termination:", eni['Attachment']['DeleteOnTermination'])
        print("Status:", eni['Status'])
        print("Source/Dest Check:", eni['SourceDestCheck'])
                
        print("-" * 40)
    print()
    print(f"The Total Ec2 Instacces Created are: ", total_ec2)
# Out:
# ID: i-0d62ab2e0367f1cac
# Name: ['MyInstance']
# Type: t2.micro
# State: running
# Private IP: 172.31.89.83
# Public IP: 54.211.157.154
# AZ: us-east-1b
# Key Pair: keyPair-MyInstance
# Launch Time: 2025-07-10 14:25:47+00:00
#
# ENI ID: eni-0e0e8964af590bce7
# Private IP: 172.31.89.83
# Public IP: 54.211.157.154
# Public DNS: ec2-54-211-157-154.compute-1.amazonaws.com
# Subnet ID: subnet-037d4834473ad1480
# VPC ID: vpc-0d3865d7d40a5d547
# MAC Address: 12:56:96:d0:42:cf
# Security Group(s): ['launch-wizard-3']
# Delete on Termination: True
# Status: in-use
# Source/Dest Check: True
# ----------------------------------------
#
# The Total Ec2 Instacces Created are:  1
# ID: i-03da77c39f993ed10
# Name: ['Instance2']
# Type: t2.micro
# State: running
# Private IP: 172.31.86.90
# Public IP: 52.207.233.177
# AZ: us-east-1b
# Key Pair: Instance2-KeyPair
# Launch Time: 2025-07-10 20:31:09+00:00
#
# ENI ID: eni-0f5341923cfba7299
# Private IP: 172.31.86.90
# Public IP: 52.207.233.177
# ...

# %%
pip install pandoc
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#                                               0.0/128.0 kB ? eta -:--:--
#      ---------                               30.7/128.0 kB 1.3 MB/s eta 0:00:01
#      -----------                           41.0/128.0 kB 495.5 kB/s eta 0:00:01
#      -----------                           41.0/128.0 kB 495.5 kB/s eta 0:00:01
#      -----------                           41.0/128.0 kB 495.5 kB/s eta 0:00:01
#      -----------                           41.0/128.0 kB 495.5 kB/s eta 0:00:01
#      -----------                           41.0/128.0 kB 495.5 kB/s eta 0:00:01
#      -----------                           41.0/128.0 kB 495.5 kB/s eta 0:00:01
#      -----------                           41.0/128.0 kB 495.5 kB/s eta 0:00:01
#      -----------                           41.0/128.0 kB 495.5 kB/s eta 0:00:01
# ...
